# %%
n = 5

for i in range(6):
    print("*",end="")
    for i in range(i):
        print("*")

# %%
n = 5

for i in range(6):
    # print(" "*2)
    for j in range(6-i):

        print("*",end=" ")




    print() # enter print krne k leye

# %%
scalable= 10

for i in range(scalable):
    print(" "*(scalable-i),end="")
    for j in range(i):
        print("*",end=" ")

    if j != scalable -1:
        print()

# for p in range(30):
#     print(" "*(p),end="")
#     for k in range(30-p):
#         print("*",end=" ")
#     print()

# %%
scalable= 10

for i in range(scalable):
    print(" "*(i),end="")
    for j in range(scalable-i):
        print("*",end="")

    # if j != scalable -1:
    print()


for p in range(scalable):
    print(" "*(scalable-p),end="")
    for k in range(p+2):
        print("*",end="")

    # if p != scalable -1:
    print()


# for p in range(30):
#     print(" "*(p),end="")
#     for k in range(30-p):
#         print("*",end=" ")
#     print()
# Out:
# **********
#  *********
#   ********
#    *******
#     ******
#      *****
#       ****
#        ***
#         **
#          *
#           **
#          ***
#         ****
#        *****
#       ******
#      *******
#     ********
#    *********
#   **********
#  ***********
