# %%
n = 5

for i in range(6):
    print("*",end="")
    for i in range(i):
        print("*")
# Out:
# ***
# **
# *
# **
# *
# *
# **
# *
# *
# *
# **
# *
# *
# *
# *

# %%
n = 5

for i in range(6):
    # print(" "*2)
    for j in range(6-i):

        print("*",end=" ")




    print() # enter print krne k leye
# Out:
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
