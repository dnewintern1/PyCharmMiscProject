# %%
while True:
    try:
        input_var = int(input("Please enter a no."))
        break
    except ValueError:
        print("value is not an integer")

# %%
#for limiting the no. of attempts the user is given the input option

attempts = 0

while True:

    try:
        input_var = int(input("Please enter a no."))
        break

    except ValueError:
        attempts += 1

        if attempts <= 3:
            print('that was not a valid no. try again')

        else:
            print('you really wanted to input a string we weill handle it')
            input_var = str(input_var)
            #print(input_var)
            break
# Out:
# that was not a valid no. try again
# that was not a valid no. try again
# that was not a valid no. try again
# you really wanted to input a string we weill handle it
# 45

# %%
import time
try:
    time.sleep(111)

except KeyboardInterrupt:
    print('you really wanted to input a string we weill handle it')
# Out:
# you really wanted to input a string we weill handle it
