# %%
from cffi.model import const_voidp_type
from prompt_toolkit.key_binding.bindings.mouse import typical_mouse_events


class Shape:
    pass

class Shape():
    pass

class Shape(object):
    pass

# %%
class Shape:

    def __init__(self, shape_type):
        self.__type = shape_type

    def get_type(self):
        return self.__type

circle = Shape("circle")

type(circle)
# Out:
# __main__.Shape

# %%
class Shape():

    def __init__(self, shape_type, color='Red'):
        self.__type = shape_type
        self.__color = color

    def get_type(self):
        return self.__type

    def get_color(self):
        return self.__color

# %%
circle = Shape("circle")
circle.get_color()
# Out:
# 'Red'

# %%
circle = Shape("circle","BLue")
circle.get_color()
# Out:
# 'BLue'

# %%
class Shape:

    def __init__(self, shape_type, color='Red'):
        self.__type = shape_type
        self.__color = color

    def get_type(self):
        return self.__type
    def get_area(self):
        pass
    def get_perimeter(self):
        pass

    def get_color(self):
        return self.__color

# %%
class Circle(Shape):
    pass

circle = Circle("circle")
type(circle)
# Out:
# __main__.Circle

# %%
class Square(Shape):
    pass


square = Square('square')
type(square)
# Out:
# __main__.Square

# %%
class Circle(Shape):

    def __init__(self):
        Shape.__init__(self,"circle")


class Square(Shape):

    def __init__(self):
        Shape.__init__(self,"square")

circle = Circle()

square = Square()

type(square), type(circle)
# Out:
# (__main__.Square, __main__.Circle)

# %%
circle.get_perimeter()

# %%
class Square(Shape):
    def __init__(self,color):
        Shape.__init__(self,"square",color)

sq = Square("square")

sq.get_color()
# Out:
# 'square'

# %%
#defining implimentation of the base class

import math

class Circle(Shape):

    def __init__(self,radius):
        Shape.__init__(self, 'circle')

        self.__radius = radius

    def get_area(self):
        return math.pi * self.__radius * self.__radius

    def get_perimeter(self):
        return 2 * math.pi * self.__radius

# %%
class Square(Shape):

    def __init__(self,side):
        Shape.__init__(self, 'square')

        self.__side = side

    def get_area(self):
        return self.__side ** 2

    def get_perimeter(self):
        return 4 * self.__side

# %%
class Competition:
    __raise_amount = 1.10

    def __init__(self, name,prize):
        self.__name = name
        self.__prize = prize

    def get_name(self):
        return self.__name

    def get_prize(self):
        return self.__prize

    def raise__prize(self):
        self.__prize *= self.__raise_amount

# %%
race = Competition("Race",1000)

# %%
type(race)
# Out:
# __main__.Competition

# %%
help(Competition)
# Out:
# Help on class Competition in module __main__:
#
# class Competition(builtins.object)
#  |  Competition(name, prize)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name, prize)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  get_name(self)
#  |
#  |  get_prize(self)
#  |
#  |  raise__prize(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
Competition.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '_Competition__raise_amount': 1.1,
#               '__init__': <function __main__.Competition.__init__(self, name, prize)>,
#               'get_name': <function __main__.Competition.get_name(self)>,
#               'get_prize': <function __main__.Competition.get_prize(self)>,
#               'raise__prize': <function __main__.Competition.raise__prize(self)>,
#               '__static_attributes__': ('__name', '__prize'),
#               '__dict__': <attribute '__dict__' of 'Competition' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Competition' objects>,
#               '__doc__': None})

# %%
class Sprint(Competition):
    pass

help(Sprint)
# Out:
# Help on class Sprint in module __main__:
#
# class Sprint(Competition)
#  |  Sprint(name, prize)
#  |
#  |  Method resolution order:
#  |      Sprint
#  |      Competition
#  |      builtins.object
#  |
#  |  Methods inherited from Competition:
#  |
#  |  __init__(self, name, prize)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  get_name(self)
#  |
#  |  get_prize(self)
#  |
#  |  raise__prize(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Competition:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
#method resolution order
#look for the code in sprint-> compition-> builtinfunction


Competition.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '_Competition__raise_amount': 1.1,
#               '__init__': <function __main__.Competition.__init__(self, name, prize)>,
#               'get_name': <function __main__.Competition.get_name(self)>,
#               'get_prize': <function __main__.Competition.get_prize(self)>,
#               'raise__prize': <function __main__.Competition.raise__prize(self)>,
#               '__static_attributes__': ('__name', '__prize'),
#               '__dict__': <attribute '__dict__' of 'Competition' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Competition' objects>,
#               '__doc__': None})

# %%
Sprint.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__static_attributes__': (),
#               '__doc__': None})

# %%
sprint = Sprint("100m",700)

# %%
sprint.__dict__
# Out:
# {'_Competition__name': '100m', '_Competition__prize': 700}

# %%
sprint.get_name()
# Out:
# '100m'

# %%
sprint.get_prize()
# Out:
# 700

# %%
sprint.raise__prize()

# %%
sprint.get_prize()
# Out:
# 770.0000000000001

# %%
chess = Competition("Chess",1000)

# %%
chess.get_prize()
# Out:
# 1000

# %%
chess.raise__prize()

# %%
chess.get_prize()
# Out:
# 1100.0

# %%
class Cycling(Competition):

    def __init__(self, name,prize, country):
        super().__init__(name,country)

        self.__country = country

    def get_country(self):
        return self.__country

# %%
cycling = Cycling ('10km', 7500,'USA')
cycling.get_country()
# Out:
# 'USA'

# %%
issubclass(Cycling, Competition)
# Out:
# True

# %%
class Shooting():

    def __init__(self, name):
        self.first = name

issubclass(Shooting,Competition)
# Out:
# False

# %%
#working with multiple inheritance

class Father:
    pass

class Mother:
    pass

class Child1(Father,Mother):
    pass

help(Child1)
# Out:
# Help on class Child1 in module __main__:
#
# class Child1(Father, Mother)
#  |  Method resolution order:
#  |      Child1
#  |      Father
#  |      Mother
#  |      builtins.object
#  |
#  |  Data descriptors inherited from Father:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
class Child2(Mother,Father):
    pass

# %%
class Father:
    def heither(self):
        print(' I Have inherited my height from father')

class Mother:
    def intellegence(self):
        print('i have inherited this intellegence forom my mother')


class Child(Father,Mother):
    def experience(self):
        print('my exp are all my own')

c = Child()
c.experience()
c.heither()
c.experience()
# Out:
# my exp are all my own
#  I Have inherited my height from father
# my exp are all my own

# %%
#emoployee

class Employee:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age
    def show_name(self):
        print(self.__name)

    def show_age(self):
        print(self.__age)

class Salary:
    def __init__(self, salary):
        self.__salary = salary

class Database(Employee, Salary):
    def __init__(self,name,age,salary):
        Employee.__init__(self,name,age)
        Salary.__init__(self,salary)

ep1 = Database("radhe",24,23000)

# %%
ep1.show_age()
ep1.show_name()
# Out:
# 24
# radhe

# %%
help(Database)
# Out:
# Help on class Database in module __main__:
#
# class Database(Employee, Salary)
#  |  Database(name, age, salary)
#  |
#  |  Method resolution order:
#  |      Database
#  |      Employee
#  |      Salary
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name, age, salary)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Employee:
#  |
#  |  show_age(self)
#  |
#  |  show_name(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Employee:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
#MultipleAndMultipleInhertance
#multi level inhertance


class Grandparent:

    def height(self):
        print("I have inherited my height from my grandparent")

class Parent(Grandparent):

    def Intelligence(self):
        print("I have inherited my Intelligence from my Parents")

class Child(Parent):

    def Experience(self):
        print("My experience is all my own")

c = Child()

c.height()
c.Intelligence()
c.Experience()
# Out:
# I have inherited my height from my grandparent
# I have inherited my Intelligence from my Parents
# My experience is all my own

# %%
help(Child)
# Out:
# Help on class Child in module __main__:
#
# class Child(Parent)
#  |  Method resolution order:
#  |      Child
#  |      Parent
#  |      Grandparent
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  Experience(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Parent:
#  |
#  |  Intelligence(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Grandparent:
#  |
#  |  height(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Grandparent:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
#example of multiple inheritence

class Grandparent(object):

    def __init__(self,city):
        self.__city = city

    def get_city(self):
        return self.__city

class Parent(Grandparent):

    def __init__(self,city,lastname):
        self.__lastname = lastname
        Grandparent.__init__(self,city)

    def get_lastname(self):
        return self.__lastname



class Person(Parent):
    def __init__(self,city,lastname,firstname):
        Parent.__init__(self,city,lastname)
        self.__firstname = firstname

    def get_firstname(self):
        return self.__firstname

    def get_introduction(self):
        lastname = super().get_lastname()
        city = super().get_city()

        print('Hi I am %s %s from %s' % (self.__firstname,lastname,city))

    def get_information(self):

        lastname = self.get_lastname()
        city = self.get_city()

        print('Hi I am %s %s from %s' % (self.__firstname,lastname,city))

# %%
s1 = Person('radhe','allahabad','NY')
s1.get_firstname()
s1.get_introduction()

s1.get_information()
# Out:
# Hi I am NY allahabad from radhe
# Hi I am NY allahabad from radhe

# %%
#polymorphism extremely imp concept


class BankAccount:
    def __init__(self,balance):
        self.__balance = balance

    def deposit(self,amount):
        self.__balance += amount

        print('the amount you have to deposit: ', self.__balance)

    def withdraw(self,amount):
        self.__balance = self.__balance - amount
        print('the amount you have to withdraw: ', self.__balance)

# %%
monk = BankAccount(15000)
monk.deposit(100)
monk.withdraw(100)
# Out:
# the amount you have to deposit:  15100
# the amount you have to withdraw:  15000

# %%
class Employee:

    def __init__(self,name,age):
        self.__name = name
        self.__age = age

    def get_name(self):
        return self.__name
    def get_age(self):
        return self.__age

    def set_name(self,NewName):
        self.__name = NewName
        print("the name has been changed to :" , NewName)

    def get_total_pay(self):
        pass



class FullTimeEmployee(Employee):
    def __init__(self, name, age, salary):
        Employee.__init__(self, name,age)
        self.__salary = salary

    def get_salary(self):
        return self.__salary

    def set_name(self,new_sallary):
        self.__salary = new_sallary
        print("the name has been changed to :" , new_sallary)

    def get_total_pay(self):
        return self.__salary

class ContractTimeEmployee(FullTimeEmployee):
    def __init__(self, name, age, salary,on_contract = True):
        Employee.__init__(self, name, age)
        FullTimeEmployee.__salary = salary
        self.__on_contract = on_contract

    def get_salary(self):
        return self.__salary

    def get_status_of_employee(self):
        return self.__on_contract

    #
    # def on_contract(self.):
    #     __salary = new_sallary
    #     print("the name has been changed to :" , new_sallary)
    #
    def get_total_pay(self):
        return self.__salary*2

# %%
s1 = Employee("radhe",23)

# %%
# s1.get_age(),s1.get_name()
s1.set_name("radheeeee")
# Out:
# the name has been changed to : radheeeee

# %%
s1.get_name()
# Out:
# 'radheeeee'

# %%
s2 = ContractTimeEmployee("radheeeee", 23, 23000)
s2.get_total_pay()
# Out:
# 46000

# %%
s2 = FullTimeEmployee("radheeeee", 23, 23000)
s2.get_total_pay()
# Out:
# 23000
