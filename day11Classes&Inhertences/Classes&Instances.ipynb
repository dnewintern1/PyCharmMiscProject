# %%
class student:
    pass

type(student)
# Out:
# type

# %%
obj1 = student()
obj2 = student()
obj3 = student()

obj1

# %%
isinstance(obj1, student)
# Out:
# True

# %%
isinstance(obj4, student)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 isinstance(obj4, student)
#
# NameError: name 'obj4' is not defined

# %%
obj4= {}

isinstance(obj4, student)
# Out:
# False

# %%
obj1.name = "radhe"
obj1.email = "radhe@gmai.com"

obj1.name
# Out:
# 'radhe'

# %%
obj1.school
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 obj1.school
#
# AttributeError: 'student' object has no attribute 'school'

# %%
obj2.name = "chad"
obj2.email = "chad@gmail."

# %%
obj2.name
# Out:
# 'chad'

# %%
obj3.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 obj3.name
#
# AttributeError: 'student' object has no attribute 'name'

# %%
class student:
    name = ''
    score = 0
    active = True

s1 = student()
s1.name,s1.score
# Out:
# ('', 0)

# %%
s1.name = "radhe"

# %%
s1.name
# Out:
# 'radhe'

# %%
s2 = student()
s2.name = "chad"

# %%
s1.name
#s2.name
# Out:
# 'radhe'

# %%
s2.name
# Out:
# 'chad'

# %%
s2.active = False

# %%
s1.name,s1.score,s1.active
# Out:
# ('radhe', 0, True)

# %%
s2.name,s2.score,s2.active
# Out:
# ('chad', 0, False)

# %%
#initializing the class objects

class Student:

    def __init__(self):

        print("Initialize called!")

s1 = Student()
# Out:
# Initialize called!

# %%
s2 = Student()
s3 = Student()
# Out:
# Initialize called!
# Initialize called!

# %%
class Student:

    def __init__():

        print("Initialize called!")

s1 = Student()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 7
#       3     def __init__():
#       5         print("Initialize called!")
# ----> 7 s1 = Student()
#
# TypeError: Student.__init__() takes 0 positional arguments but 1 was given

# %%
class Student:

    def __init__(boo): #standard practice is to call it self

        print("Initialize called!")

s1 = Student()
# Out:
# Initialize called!

# %%
class Student:

    def __init__(self,name):

        self.name = name
        self.mail = name + "." +"@xyz.com"

        # print("Initialize called!")

s1 = Student("radhe")

# %%
s1.name,s1.mail
# Out:
# ('radhe', 'radhe.@xyz.com')

# %%
print(s1)

# %%
s1.name
# Out:
# 'radhe'

# %%
s2 = Student("chad")

# %%
s2.name,s2.mail
# Out:
# ('chad', 'chad.@xyz.com')

# %%
s2.name , s2.mail
# Out:
# ('chad', 'chad.@xyz.com')

# %%
s2.name,s1.name
# Out:
# ('chad', 'radhe')

# %%
class Student:

    def __init__(self,first,last):

        self.first = first
        self.last = last

        self.mail = first + "." +last+ "@xyz.com"

    def fullname(self):
        return '{} {}'.format(self.first, self.last)

s1 = Student('radhe', ' Joseph')
print(s1.fullname())
# s1.fullname()
        # print("Initialize called!")

# s1 = Student()
# Out:
# radhe Joseph

# %%
s1.fullname()
# Out:
# 'radhe Joseph'

# %%
s2 = Student('Usa', ' seph')
print(s2.fullname())
# Out:
# Usa seph

# %%
Student.fullname(s1)
# Out:
# 'radhe Joseph'

# %%
del s1.first

# %%
s1.fullname()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 s1.fullname()
#
# Cell In[45], line 11, in Student.fullname(self)
#      10 def fullname(self):
# ---> 11     return '{}{}'.format(self.first, self.last)
#
# AttributeError: 'Student' object has no attribute 'first'

# %%
# del s2 # third class

class Student:

    def __init__(self,first,last):

        self.first = first
        self.last = last

        self.mail = first + "." +last+ "@xyz.com"

    def fullname(self):
        return '{} {}'.format(self.first, self.last)

    def uppercase(self):

        self.first = self.first.upper()
        self.last = self.last.upper()

s1 = Student('radhe', 'Joseph')
s2 = Student('Usa', 'seph')

# %%
s1.fullname()
s1.uppercase()
s1.fullname()
# Out:
# 'RADHE JOSEPH'

# %%
class Competition:
    raise_amount = 1.04

    def __init__(self, name,prize):

        self.name = name #instance attribuess / variable
        self.prize = prize #instance variable associated with an instance or object of a class and not the class itself

    def raise_prize(self):
        self.prize = self.prize * Competition.raise_amount

# %%
debate = Competition('Debat',100)

Competition.raise_amount
# print(debate.raise_amount())
# print(Competition.raise_amount)
# Competition.
# Out:
# 1.04

# %%
essay = Competition('Essay',100)
essay.prize
# Out:
# 100

# %%
essay.raise_prize()

# %%
essay.prize
# Out:
# 104.0

# %%
simpulations = Competition("Simulations", 1000)

simpulations.raise_amount
# Out:
# 1.04

# %%
simpulations.__dict__
# Out:
# {'name': 'Simulations', 'prize': 1000}

# %%
Competition.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'raise_amount': 1.04,
#               '__init__': <function __main__.Competition.__init__(self, name, prize)>,
#               'raise_prize': <function __main__.Competition.raise_prize(self)>,
#               '__static_attributes__': ('name', 'prize'),
#               '__dict__': <attribute '__dict__' of 'Competition' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Competition' objects>,
#               '__doc__': None})

# %%
Competition.__name__
# Out:
# 'Competition'

# %%
Competition.raise_amount = 10.3

# %%
Competition.raise_amount
# Out:
# 10.3

# %%
simpulations.raise_amount = 100

# %%
Competition.raise_amount
# Out:
# 10.3

# %%
simpulations.raise_amount
# Out:
# 100

# %%
class Competition:

    participants = []

    def __init__(self, name, prize):

        self.name = name
        self.prize = prize

# %%
debate = Competition('Debat',100)

debate.participants
# Out:
# []

# %%
Competition.participants.append("radhe")
Competition.participants
# Out:
# ['radhe']

# %%
debate.participants
# Out:
# ['radhe']

# %%
debate.participants.append("karan")

# %%
debate.participants
# Out:
# ['radhe', 'karan']

# %%
Competition.participants
# Out:
# ['radhe', 'karan']

# %%
essay = Competition("esssay", 1000)

essay.participants
# Out:
# ['radhe', 'karan']

# %%
Competition.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'participants': ['radhe', 'karan'],
#               '__init__': <function __main__.Competition.__init__(self, name, prize)>,
#               '__static_attributes__': ('name', 'prize'),
#               '__dict__': <attribute '__dict__' of 'Competition' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Competition' objects>,
#               '__doc__': None})

# %%
#working with Instance variable

class Competition:



    def __init__(self, name, prize):

        self.name = name
        self.prize = prize
        self.participants = []

# %%
essay = Competition("esssay", 1000)

essay.participants
# Out:
# []

# %%
print(essay.participants)
essay.participants.append("ishika")
print(essay.participants)
# Out:
# []
# ['ishika']

# %%
essay = Competition("esssay", 1000)
essay.participants
# Out:
# []

# %%
class Dog():

    def __init__(self, name,breed):

        self.__name = name
        self.__breed = breed

    def print_details(self):
        print("Name:", self.__name , "|| Breed:", self.__breed)

# %%
d1 = Dog("Donald","Doberman")
d1.print_details()
# Out:
# Name: Donald || Breed: Doberman

# %%
d1.name = "NEwname"

d1.print_details()
# Out:
# Name: Donald || Breed: Doberman

# %%
Dog.__dict__

# d1.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Dog.__init__(self, name, breed)>,
#               'print_details': <function __main__.Dog.print_details(self)>,
#               '__static_attributes__': ('__breed', '__name'),
#               '__dict__': <attribute '__dict__' of 'Dog' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Dog' objects>,
#               '__doc__': None})

# %%
d1.__dict__

d1.__name = "OBA"

# %%
d2 = Dog("trump","chuaua")
d2.print_details()
# Out:
# Name: trump || Breed: chuaua

# %%
d2.__name = "newDOGOOOOO"
d2.print_details()
# Out:
# Name: trump || Breed: chuaua

# %%
d2.__dict__
# Out:
# {'_Dog__name': 'trump',
#  '_Dog__breed': 'chuaua',
#  '__name': 'newDOGOOOOO',
#  'name': 'newDOGOOOOO'}

# %%
d2._Dog__name = "the Varible got hacked"

# %%
d2.__dict__
# Out:
# {'_Dog__name': 'the Varible got hacked',
#  '_Dog__breed': 'chuaua',
#  '__name': 'newDOGOOOOO',
#  'name': 'newDOGOOOOO'}

# %%
d2.print_details()
# Out:
# Name: the Varible got hacked || Breed: chuaua

# %%
class Dog():

    def __init__(self, name,breed):

        self.__name = name
        self.__breed = breed

    def print_details(self):
        print("Name:", self.__name , "|| Breed:", self.__breed)

    def chang_name(self,__name):
        self.__name = self.__name#_Dog__name

# %%
d1 = Dog("Nemo","Husky")

d1.print_details()
# Out:
# Name: Nemo || Breed: Husky

# %%
d1.chang_name("gion")

# %%
d1.print_details()
# Out:
# Name: Nemo || Breed: Husky

# %%
class Dog:

    __species = 'canine'

    def __init__(self,name,breed):

        self.__name = name #the trick to make it private in python
        self.__breed = breed
        self.__tricks = []


    def get_name(self):
        return self.__name

    def set_name(self, __name):
        self.__name = __name

    def get_breed(self):
        return self.__breed

    def set_breed(self, new_breed):
        self.__breed = new_breed

    def add_trick(self,trick):
        self.__tricks.append(trick)

    def print_details(self):
        print("My name is %s and I am a %s and I can do tricks: %s" % (self.__name, self.__breed,self.__tricks))

# %%
d1 = Dog("mojo","theGoldeee")

d1.print_details()

# Dog.__dict__
# Out:
# My name is mojo and I am a theGoldeee and I can do tricks: []

# %%
d1.add_trick("roll Over")
d1.print_details()
d1.__dict__
# Out:
# My name is mojo and I am a theGoldeee and I can do tricks: ['roll Over']
# {'_Dog__name': 'mojo',
#  '_Dog__breed': 'theGoldeee',
#  '_Dog__tricks': ['roll Over']}

# %%
d1.set_breed("erererer")
d1.print_details()
# Out:
# My name is mojo and I am a erererer and I can do tricks: ['roll Over']

# %%
d2 = Dog('love','loosepbreed')
d2.print_details()

d2.set_breed("newBREEDUPDATED")
# Out:
# My name is love and I am a loosepbreed and I can do tricks: []
