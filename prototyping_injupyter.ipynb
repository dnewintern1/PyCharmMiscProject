# %%
num_list = [10,20,30,40,50,60,70]

def main():

    count = 0 
    total = 0 

    for i in num_list:
        count +=1
        total = total + i

        # print("element is: ", i)
        # print("")
        # print("sum :",total)
        # print( )
    print("total sum:", total)

# %%
if __name__ == "__main__":
    main()
# Out:
# element is:  10
#
# sum : 10
#
# element is:  20
#
# sum : 30
#
# element is:  30
#
# sum : 60
#
# element is:  40
#
# sum : 100
#
# element is:  50
#
# sum : 150
#
# element is:  60
#
# sum : 210
#
# element is:  70
#
# sum : 280
#
# total sum: 280
