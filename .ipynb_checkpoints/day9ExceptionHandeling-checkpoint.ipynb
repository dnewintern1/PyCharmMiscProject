# %%
from day7MoreIntoFunctions import expense

try:
    print(variable)

except:
    print("exception occured")
# Out:
# exception occured

# %%
try:
    print(variable)

except NameError:
    print("exception occured")

except:
    print("unknown error occured")
# Out:
# exception occured

# %%
f = open('log.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 f = open('log.txt')
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'log.txt'

# %%
try:
    f = open('log.txt')

except FileNotFoundError:
    print("file not found")

except:
    print("unknown error occured")
# Out:
# file not found

# %%
user = input('enter your no. here')

k = int(user)
print("a")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 user = input('enter your no. here')
#       3 k = int(user)
#       4 print("a")
#
# TypeError: 'str' object is not callable
