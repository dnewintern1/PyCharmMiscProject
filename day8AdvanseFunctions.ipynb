# %%
# !cat radomfile/textfile.txt
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
with open('randomfile/textfile.txt', 'r') as f:
    print(f.read())
# Out:
# this is the random file that i have created in the randomfiles fooulder
# this is the second ne inside
# and this is the third line that i have created
