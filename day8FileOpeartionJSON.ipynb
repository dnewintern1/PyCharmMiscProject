# %%
dessert = {"Name" : 'Ice cream',
          "Flavour" : ["Choclate", 'Pineapple'],
          "Topping" : True,
          "WaffleCone" : "Yes"}


newdict = {"name" : "radhe",
           'flavour': ['kind you','lolita'],
           'Topping' : True,
           'WaffleCone' : 'Yes'}

print(newdict.values("new":"value"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 12
#       1 dessert = {"Name" : 'Ice cream',
#       2           "Flavour" : ["Choclate", 'Pineapple'],
#       3           "Topping" : True,
#       4           "WaffleCone" : "Yes"}
#       7 newdict = {"name" : "radhe",
#       8            'flavour': ['kind you','lolita'],
#       9            'Topping' : True,
#      10            'WaffleCone' : 'Yes'}
# ---> 12 print(newdict.append(dessert))
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
import json

dessert_str = json.dumps(dessert)

dessert_str
# Out:
# '{"Name": "Ice cream", "Flavour": ["Choclate", "Pineapple"], "Topping": true, "WaffleCone": "Yes"}'

# %%
type(dessert_str)
# Out:
# str

# %%
#writing a dictionary dicrectly into a file from json

with open('testfolder/eat.txt', 'w') as json_file:
    json.dump(dessert, json_file)

# %%
dessert
# Out:
# {'Name': 'Ice cream',
#  'Flavour': ['Choclate', 'Pineapple'],
#  'Topping': True,
#  'WaffleCone': 'Yes'}

# %%
json.dumps(dessert, indent=2)
# Out:
# '{\n  "Name": "Ice cream",\n  "Flavour": [\n    "Choclate",\n    "Pineapple"\n  ],\n  "Topping": true,\n  "WaffleCone": "Yes"\n}'

# %%
json.dumps(dessert, indent=2)
json.dumps(dessert, separators = (":" , "="))
# Out:
# '{"Name"="Ice cream":"Flavour"=["Choclate":"Pineapple"]:"Topping"=true:"WaffleCone"="Yes"}'

# %%
json.dumps(dessert, separators = (":" , "~"))
# Out:
# '{"Name"~"Ice cream":"Flavour"~["Choclate":"Pineapple"]:"Topping"~true:"WaffleCone"~"Yes"}'

# %%
json.dumps(dessert, sort_keys=False)
# Out:
# '{"Name": "Ice cream", "Flavour": ["Choclate", "Pineapple"], "Topping": true, "WaffleCone": "Yes"}'

# %%
#
