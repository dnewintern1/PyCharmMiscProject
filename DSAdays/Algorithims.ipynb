# %%
def add_after(self,middle_value,dataval):

    if middle_value is None:
        print("Data to insert after is not specified")
        return

    curr = curr.head

    while curr and curr.dataval != middle_value:
        curr = curr.nextval

    new_node = Node(dataval = dataval)

    new_node.nextval = curr.nextval
    curr.nextval = new_node


def find(self,data):

    curr = self.head

    while curr and curr.dataval != data:
        curr = curr.nextval

    return curr

def remove(self,data):

    curr = self.head
    prev = None

    while curr and curr.dataval !=data:
        prev = curr 
        curr = curr.nextval


    if prev is None:
        self.head = curr.nextval

    elif curr:
        prev.nextval = curr.nextval
        curr.nextval = None


def reverse(self):

    curr = self.head

    prev_node = None
    next_node = None

    while curr:
        nextval = curr.nextval
        curr.nextval = prev_node

        prev_node = curr

        curr = nextval

    self.head = prev_node


def recursive(curr,prev):
    if not curr:
        return prev

    nextval = curr.nextval
    curr.nextval = prev

    prev = curr

    curr = nextval

    return recursive(curr,prev)

self.head = recursive(curr=head, prev=none)


def count_node(self):

    if (self.head == None):
        return 0

    else:
        curr = self.head
        count = 0
        while (curr !=None):
            curr = curr.nextvalue
            count +=1

    return count


numbers = LinkedList()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 76
#      72     curr = nextval
#      74     return recursive(curr,prev)
# ---> 76 self.head = recursive(curr=head, prev=none)
#      79 def count_node(self):
#      81     if (self.head == None):
#
# NameError: name 'head' is not defined
