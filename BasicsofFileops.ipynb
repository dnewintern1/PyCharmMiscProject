# %%
print("this ")
# Out:
# this

# %%
open("randomtest/testfile.txt")
# Out:
# <_io.TextIOWrapper name='randomtest/testfile.txt' mode='r' encoding='UTF-8'>

# %%
file = open("randomtest/testfile.txt")

# %%
file.mode
# Out:
# 'r'

# %%
file.closed
# Out:
# False

# %%
file.read()
# Out:
# 'Random shit that am typingl for testing in this line\nthe 2nd line\nthe 3rd line'

# %%
file.seek(0)
# Out:
# 0

# %%
file.read(5)
# Out:
# 'Rando'

# %%
file.tell()
# Out:
# 5

# %%
file.read(5)
# Out:
# 'm shi'

# %%
file.tell()
# Out:
# 10

# %%
file.readline()
# Out:
# 't that am typingl for testing in this line\n'

# %%
file.seek(0)
# Out:
# 0

# %%
file.readline()
# Out:
# 'Random shit that am typingl for testing in this line\n'

# %%
file.readline()
# Out:
# 'the 2nd line\n'

# %%
file.readline()
# Out:
# 'the 3rd line'

# %%
file.seek(0)
# Out:
# 0

# %%
file.readlines()
# Out:
# ['Random shit that am typingl for testing in this line\n',
#  'the 2nd line\n',
#  'the 3rd line']

# %%
file.close()

# %%
file.closed
# Out:
# True

# %%
with open("randomtest/testfile.txt") as f:
    data = f.readlines()

print(data)
# Out:
# ['Random shit that am typingl for testing in this line\n', 'the 2nd line\n', 'the 3rd line']

# %%
f.closed
# Out:
# True

# %%
#another example of with block

with open("randomtest/testfile.txt") as f:
    line = f.readline()

    while line:
        print(line)
        line=f.readline()
# Out:
# Random shit that am typingl for testing in this line
#
# the 2nd line
#
# the 3rd line

# %%
file = open("randomtest/testfile.txt", "w")

file.write("lets check if this is included in the file")

file.closed
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[11], line 4
#       1 file = open("randomtest/testfile.txt", "w")
#       3 file.write("lets check if this is included in the file")
# ----> 4 file.read()
#       6 file.closed
#
# UnsupportedOperation: not readable

# %%
file = open("randomtest/testfile.txt", "w")
file.write("lets check the write operation")
file.seek(6)
file.write("Examin")
file.close()

# %%
file = open("randomtest/testfile.txt")

for lines in file:
    print(lines)
# Out:
# lets cExaminhe write operation

# %%
#the below code is in the write mode and will over ride all the content existing in the file

with open("randomtest/testfile.txt" , 'w') as f:

    f.write("the first line in the file\n")
    f.write("the sec line in the file\n")
    f.write("the thi line in the file\n")

# %%
#the append mode you you trying to avoid overriding any content in the existing file

f =  open("randomtest/testfile.txt" , 'a') 
f.tell()
# Out:
# 77

# %%
f.writelines(["thenewwwwww first line in the file\n",
             "thenewwwwww second line in the file\n",
             "thenewwwwww thirt line in the file\n"])

f.close
# Out:
# <function TextIOWrapper.close()>

# %%
#differnt function in the file operations

f.fileno() # a no. which is used by the operating sys to identify the file
f.isatty() #which returns a boolean value to identify if it is atteched to any terminal device
f.readable() #to see if the file is rreadable or not
f.writable() #
f.close()
# Out:
# 4

# %%
f.tell
# Out:
# <function TextIOWrapper.tell()>

# %%
f =  open("randomtest/testfile.txt" , 'a') 
f.tell()
# Out:
# 77

# %%
f.truncate(50) #getting introduced to truncate fuction in pyton
# Out:
# 50

# %%
f =  open("randomtest/testfile.txt" , 'r') 
f.read()
# Out:
# 'the first line in the file\nthe sec line in the fil'

# %%
f =  open("randomtest/testfile.txt" , 'r+') 
f.writelines("In 'R+', the cursor is initially at the start of the line")
f.close()

# %%
f =  open("randomtest/testfile.txt" , 'r')

f.read()
# Out:
# "In 'R+', the cursor is initially at the start of the linehi line in the file\n"

# %%
f =  open("randomtest/testfile.txt" , 'a+') 
f.writelines("In 'A+', the cursor is initially at the end of the line")

f.close()

# %%
f =  open("randomtest/testfile.txt" , 'r')
f.read()
# Out:
# "In 'R+', the cursor is initially at the start of the linehi line in the file\nIn 'A+', the cursor is initially at the end of the line"

# %%
#renaming a file from the command line

import os
os.rename("randomtest/testfile.txt" , 'a+', ")
