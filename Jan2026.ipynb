# %%
from day4 import age_from_user

name = "radhe"
city = "noida"

print("My name is " + name + " and i live in " + city + ".")
print("My name is " , name , " and i live in " , city , "." , sep="")
print(f"My name is {name} and i live in {city}.")
print("My name is {} and i live in {}.".format(name, city))
# Out:
# My name is radhe and i live in noida.
# My name is radhe and i live in noida.
# My name is radhe and i live in noida.
# My name is radhe and i live in noida.

# %%
# taking input from the user

day = input("what day it is.")
print(day)
print(type(day))
# Out:
# radhe
#
# <class 'str'>

# %%
print(f"hello,nice to meet you? the day")
# Out:
# hello,nice to meet you? the day

# %%
# score = input("what is your score")
# print(score*2)
score = "100"
print(type(score))
score = int(score)

print(type(score))
# Out:
# <class 'str'>
# <class 'int'>

# %%
days_per_week = ""some random text""
sentence = "the number of days in a week " + str(days_per_week)
print(sentence)
# Out:
#   Cell In[31], line 1
#     days_per_week = ""some random text""
#                       ^
# SyntaxError: invalid syntax

# %%
age_in_years = int(input("How old are you? "))
age_in_years = age_in_years*2

# %%
#reintroduction to tupes

# fruits = ("apple", "banana", 90)
# print(fruits)
#
# numbers = (1, 2, 3, 4)
# print(numbers)
#
# person = ("Alice", 30, True)
# print(person)


#importance of single comma in order to initialize a single tuple

single_item = ("apple",)
print(type(single_item))
# Out:
# <class 'tuple'>

# %%
colors = ("red", "green", "blue")
print(colors[0])   # "red"
print(colors[2])   # "blue"
print(colors[1])
# Out:
# red
# blue
# green
