# %%
import json

car = """{ "model" : "Civic", "make" : "Japines" , "Variant" : ["barbad" , "bhothebab"]}"""

car
# Out:
# '{ "model" : "Civic", "make" : "Japines" , "Variant" : ["barbad" , "bhothebab"]}'

# %%
car_dict = json.loads(car)

# %%
car_dict
# Out:
# {'model': 'Civic', 'make': 'Japines', 'Variant': ['barbad', 'bhothebab']}

# %%
with open("randomtest/Currency.json") as json_file:
    data = json.load(json_file)
    print(data)
# Out:
# {'Country': 'USA', 'Currancy': 'United States Dollar'}

# %%
#there is another function for reversing the above code for getting the dictionary into a json file
Currency = {'name':"radhe", 'class':"first","native":"allahabad"}
json_var = json.dumps(Currency)

# %%
print(json_var)
# Out:
# {"name": "radhe", "class": "first", "native": "allahabad"}

# %%
with open("randomtest/Currency.json" , 'w') as jsonfile:
    jsonfile.write(json_var)

# %%
with open("randomtest/Currency.json") as json_file:
    data = json.load(json_file)
    print(data)
# Out:
# {'name': 'radhe', 'class': 'first', 'native': 'allahabad'}
